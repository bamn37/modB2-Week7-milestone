# %% [markdown]
# # Week 10 - Introduction to Modeling

# %% [markdown]
# # 1. Lesson

# %% [markdown]
# Last week, we reviewed one model: linear regression.  This week, we are going to review another, called random forest.  The random forest model builds many decision trees, then averages their estimates to make a prediction.
#
# You will also perform:
# * Cross-validation
# * Hyperparameter tuning
# * A performance metric (root mean squared error)
#
# ### How does random forest work?
#
# A random forest is a set of decision trees.  Let's say we use n_estimators = 100 decision trees, and we have ten features.  Then each decision tree is built so that a given branch gets about three (sqrt(10)) features to choose from.  It starts from the top of the tree, selects the best feature, then proceeds to the next nodes.  The best feature is the one that minimizes the mean squared error, which must be computed for both branches, weighted according to the probability of each branch, and then summed over both branches.

# %%
# %pip install pandas numpy scikit-learn matplotlib

import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import root_mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
# Out:
# Requirement already satisfied: pandas in /usr/local/python/3.12.1/lib/python3.12/site-packages (3.0.2)
# Requirement already satisfied: numpy in /usr/local/python/3.12.1/lib/python3.12/site-packages (2.4.4)
# Requirement already satisfied: scikit-learn in /usr/local/python/3.12.1/lib/python3.12/site-packages (1.8.0)
# Requirement already satisfied: matplotlib in /usr/local/python/3.12.1/lib/python3.12/site-packages (3.10.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Here, we build three series of random numbers between 0 and 1.  We use a somewhat arbitrary formula to construct the synthetic data.  The fourth value (the target) equals the first series minus twice the second, with the whole then being multiplied by the third series.  If we stopped here, the target would be completely dependent on the three feature series - it would be easy to predict.  However, we then add a random normal distribution to make the prediction harder.
#
# There are a train series and a test series, with different features ("a" and "b"), and with different random normal data added.  This tests whether our model can predict new data.  We fit to the "a" features using the train_target, then predict the test_target using the "b" features.

# %%
np.random.seed(0)
num_points = 10000
feature_1a = np.random.random(size = num_points) * 3
feature_2a = np.random.random(size = num_points) * 3
feature_3a = np.random.random(size = num_points) * 3
train_target = (feature_1a - 2 * feature_2a) * feature_3a + np.random.normal(size = num_points)
feature_1b = np.random.random(size = num_points) * 3
feature_2b = np.random.random(size = num_points) * 3
feature_3b = np.random.random(size = num_points) * 3
test_target = (feature_1b - 2 * feature_2b) * feature_3b + np.random.normal(size = num_points)
train_df = pd.DataFrame({"f1": feature_1a, "f2": feature_2a, "f3": feature_3a})
test_df = pd.DataFrame({"f1": feature_1b, "f2": feature_2b, "f3": feature_3b})
rf = RandomForestRegressor()
rf.fit(train_df.values, train_target)
# Out:
# RandomForestRegressor()

# %% [markdown]
# As expected, the RMSE is smallest when predicting the training data, larger when predicting the testing data, and largest when comparing random (shuffled) data instead of using a prediction.  In the last case, there is no attempt to make a good prediction.  The small RMSE when predicting the training data indicates that the model has "memorized" the training data to some degree.

# %%
print("RMSE when predicting training data:")
print(root_mean_squared_error(rf.predict(train_df.values), train_target))
print("RMSE when predicting testing data:")
print(root_mean_squared_error(rf.predict(test_df.values), test_target))
test_target_shuffle = test_target.copy()
np.random.shuffle(test_target_shuffle)
print("RMSE with random predictions:")
print(root_mean_squared_error(test_target_shuffle, test_target))
# Out:
# RMSE when predicting training data:
# 0.40446903790544014
# RMSE when predicting testing data:
# 1.0666204347667474
# RMSE with random predictions:
# 5.262103337484077

# %% [markdown]
# Next, we perform a Grid Search over various parameters.  We've used a small number of parameters here, but you could add more.  The first parameter, n_estimators, shows the number of decision trees in the random forest.  The second, max_depth, is the maximum depth of each tree.  By picking three n_estimators values (10, 33, 100) and three max_depth values (2, 4, None), we allow for nine parameter combinations.  For example, (n_estimators = 10, max_depth = 2) is a combination.  The grid search tries all nine combinations and uses cross validation to choose the best one.  This is done below.
#
# ### What is cross validation?
#
# Cross validation is a way to find out which parameter combination is the best.  With 5-fold cross validation (the default) we divide the data into five equal-sized groups.  Four of them are used as training data and the fifth is testing data.  The score (in this case the root mean squared error) on the testing data is recorded.  This is done for each split: that is, each fifth is taken out and used as testing data; then, the five root mean squared errors (from taking out the five fifths, one at a time) are averaged.
#
# We now have root mean squared error value for each parameter combination, allowing us to choose the best combination.

# %%
np.random.seed(0)
gcv = GridSearchCV(estimator = RandomForestRegressor(), param_grid = {"n_estimators": [10, 33, 100], "max_depth": [2, 4, None]}, \
                   scoring = "neg_root_mean_squared_error")
gcv.fit(train_df.values, train_target)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [2, 4, None],
#                          'n_estimators': [10, 33, 100]},
#              scoring='neg_root_mean_squared_error')

# %%
print(gcv.best_estimator_)
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# RandomForestRegressor()
# {'max_depth': None, 'n_estimators': 100}
# -1.0851425903159186

# %%
gcv.cv_results_["mean_test_score"] # There are nine scores, one for each of the 3 x 3 hyperparameter combinations
# Out:
# array([-2.27296628, -2.26369708, -2.26370023, -1.56063403, -1.52732923,
#        -1.52615891, -1.12289873, -1.09373829, -1.08514259])

# %% [markdown]
# ### Why does n_estimators grow like 10, 33, 100 instead of like 1, 50, 100?
#
# First of all, we can make it grow however we want.  The question is why we chose 10, 33, 100.  The idea here is that when you have no idea what is the appropriate number, you should pick guesses that grow exponentially.  For example, suppose you are trying to guess the height of a particular tree.  You look online and find that redwoods grow to 400 feet high, while bonsai trees may be as short as six inches.  If you get three guesses, you could guess: one foot, 200 feet, 400 feet.  These guesses would be linearly spaced out.  However, the 200 foot guess feels wrong - it's still very tall.  Most trees don't grow that tall.  Instead, let's make a geometric progression:

# %%
list(map(round, [400**0, 400**0.25, 400**0.5, 400**0.75, 400*1]))
# Out:
# [1, 4, 20, 89, 400]

# %% [markdown]
# Now the guesses are four feet, 20 feet, and 89 feet.  (We'll drop the initial 1 and the final 400.) That feels more plausible: the middle value, 20 feet, is representative of many actual trees in a way that the middle 200 foot guess wasn't.

# %% [markdown]
# # 2. Weekly graph question

# %% [markdown]
# In words, please summarize what this graph shows.

# %% [markdown]
# the graph below shows two key concepts that are nice to understand.  number one as the model trains on more data (x axis) the rmse (y axis) goes down.  At first when the model has little data to train on the rmse is relatively high.   then as new data is added for which the model can learn from then the model improves quickly.  after that initial quick improvement the error continues to decrease but not by much.   This shows the diminishing returns of adding more data.  This is basically the noise floor of the data beyond which not much improvement can be made.  by the time the curve has flattened the model has "learned" the structure and underlying function of the data as best it can and the remaining error is just due to irreducible noise present in the system and any inherent bias in the model (tree regressor in the instance).

# %%
rmse_lst = list()
for x in range(round(num_points / 20), num_points, round(num_points / 20)):
    rf.fit(train_df.values[0:x,:], train_target[0:x])
    rmse_lst.append(root_mean_squared_error(rf.predict(test_df.values), test_target))

# %%
import matplotlib.pyplot as plt

plt.plot(rmse_lst)

# %% [markdown]
# # 3. Homework

# %% [markdown]
# In this exercise, you will try to predict the change of one stock based on the change in ten other stocks.

# %%
def make_X_y(alpha = 0.5):
    df_hwk = pd.DataFrame()
    num_samples_hwk = 10000
    common_odd = np.random.normal(size = num_samples_hwk)
    common_even = np.random.normal(size = num_samples_hwk)
    common_three = np.random.normal(size = num_samples_hwk)
    for n in range(11):
        common = np.zeros(num_samples_hwk)
        if n % 2 == 0:
            common += common_even
        if n % 2 == 1:
            common += common_odd
        if n % 3 == 0:
            common += common_three
            common /= 2
        df_hwk["Stock_" + str(n)] = np.random.normal(size = num_samples_hwk) + alpha * common
    X = df_hwk.values[:,:-1]
    y = df_hwk.values[:,-1]
    return X, y

# %% [markdown]
# The above code creates an X with ten columns, corresponding to ten different stocks.  The y is the eleventh stock.  The stocks have some commonalities: the even numbered stocks are related, as are the odds.  The stocks that are multiples of three are all related, too.  Random forest should be able to sort through all this and decide that the eleventh stock is related to the odd numbered, non-divisible-by-three stocks, and predict accordingly.  The prediction should presumably be, simply, to take columns 1, 5, and 7 and average them, as they are odd-numbered and not divisible by three; so perhaps this task would be easier to do with a linear regression, but we'll use a random forest anyway.  The value "alpha" determines how important the common element is.  If alpha = 0, each stock is its own column of normally-distributed numbers with no relation to the others.  If alpha = 10, then the great majority of the variation in the stock values comes from the common elements.
#
# ### Question:
#
# Do you predict that alpha = 0 will result in a better or worse prediction than alpha = 10?  Remember that the prediction must be performed on test data, so you'll need an X_train and y_train for training and a separate X_test and y_test for testing.  I recommend using a correlation rather than a MSE or RMSE in this case, if you want to directly compare two different predictions, because the MSE and RMSE vary with the magnitude of the data as well as with the quality of the prediction.
#
# After you make the prediction, try it out, and comment on what you learned.
#
# ### Randomized Search
#
# Use RandomizedSearchCV instead of GridSearchCV to perform cross-validation.
#
# ### Scoring
#
# Research the scoring parameters under "regression":
#
# https://scikit-learn.org/dev/modules/model_evaluation.html#scoring-parameter
#
# Choose at least one that you want to learn about, use it, and research it online.  Write something about what you've learned about it.

# %%
def corr_score(y_true, y_pred):
    return np.corrcoef(y_true, y_pred)[0, 1]

np.random.seed(42)

results = {}

for alpha in [0, 10]:
    X_train, y_train = make_X_y(alpha=alpha)
    X_test, y_test = make_X_y(alpha=alpha)

    rf = RandomForestRegressor(
        n_estimators=200,
        random_state=42,
        n_jobs=-1)
    
    rf.fit(X_train, y_train)

    y_pred = rf.predict(X_test)

    corr = corr_score(y_test, y_pred)
    results[alpha] = corr

    print(f"alpha = {alpha}")
    print(f"Test correlation = {corr:.4f}")
    print()

print("Summary:")
for alpha, corr in results.items():
    print(f"alpha = {alpha}: correlation = {corr:.4f}")
# Out:
# alpha = 0
# Test correlation = 0.0033
#
# alpha = 10
# Test correlation = 0.9927
#
# Summary:
# alpha = 0: correlation = 0.0033
# alpha = 10: correlation = 0.9927

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import make_scorer, r2_score, mean_absolute_error


corr_scorer = make_scorer(corr_score)

def run_random_search_experiment(alpha, random_state=42):
    # separate training and testing data
    X_train, y_train = make_X_y(alpha=alpha)
    X_test, y_test = make_X_y(alpha=alpha)

    rf = RandomForestRegressor(random_state=random_state)

    param_dist = {
        "n_estimators": [50, 100, 200, 300, 500],
        "max_depth": [None, 3, 5, 10, 20, 30],
        "min_samples_split": [2, 5, 10, 20],
        "min_samples_leaf": [1, 2, 4, 8],
        "max_features": [1.0, "sqrt", "log2", 0.5, 0.8]}

    scoring = {
        "r2": "r2",
        "neg_mae": "neg_mean_absolute_error",
        "corr": corr_scorer}

    search = RandomizedSearchCV(
        estimator=rf,
        param_distributions=param_dist,
        n_iter=20,
        scoring=scoring,
        refit="corr",
        cv=5,
        verbose=1,
        random_state=random_state,
        n_jobs=-1,
        return_train_score=True)

    search.fit(X_train, y_train)

    best_model = search.best_estimator_

    y_pred = best_model.predict(X_test)

    test_corr = corr_score(y_test, y_pred)
    test_r2 = r2_score(y_test, y_pred)
    test_mae = mean_absolute_error(y_test, y_pred)

    print("=" * 60)
    print(f"alpha = {alpha}")
    print("Best parameters:")
    print(search.best_params_)
    print()
    print(f"Best mean CV correlation: {search.best_score_:.4f}")
    print(f"Test correlation:         {test_corr:.4f}")
    print(f"Test R^2:                {test_r2:.4f}")
    print(f"Test MAE:                {test_mae:.4f}")
    print("=" * 60)

    return {
        "alpha": alpha,
        "search": search,
        "best_model": best_model,
        "test_corr": test_corr,
        "test_r2": test_r2,
        "test_mae": test_mae,}

np.random.seed(42)

result_alpha_0 = run_random_search_experiment(alpha=0, random_state=0)
result_alpha_10 = run_random_search_experiment(alpha=10, random_state=0)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ============================================================
# alpha = 0
# Best parameters:
# {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 0.8, 'max_depth': 30}
#
# Best mean CV correlation: 0.0199
# Test correlation:         0.0038
# Test R^2:                -0.0161
# Test MAE:                0.8146
# ============================================================
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ============================================================
# alpha = 10
# Best parameters:
# {'n_estimators': 200, 'min_samples_split': 20, 'min_samples_leaf': 2, 'max_features': 0.5, 'max_depth': None}
#
# Best mean CV correlation: 0.9930
# Test correlation:         0.9929
# Test R^2:                0.9859
# Test MAE:                0.9401
# ============================================================

# %% [markdown]
# I predict that an alpha of 0 will result in a worse prediction than a higher alpha of 10.   the key is to understand how the data was created:  df_hwk["Stock_" + str(n)] = np.random.normal(size = num_samples_hwk) + alpha * common
#
# the equation above shows the each of the 10 stocks is built upon a random sample 10,000 samples.   and those 10,000 data points are then taken and the following is added to each of them:   alpha * common.    when alpha is almost zero then not much of the common stocks (odd, even, multiple of 3) data is shared.  When the alpha is large, say 10, then the stock data is dominated by the number that is added to it from the common elements.   because its dominated by the common elements the data can easily find out which ones it related to.  for instance stock number 11`(the target) is odd (not even, or divided by 3) so the regression tree should be able to "learn" that and use the odd numbered features to predict the target and not use the even or divisible by 3 since those won't give much if any info about stock 11 due to the way the data was synthesized.
#
# after trying diff alphas (see code above) this is what happened:   when alpha = 0 the test correlation was nearly zero, indicating that model could not learn anything useful since with an alpha of zero the stocks are not related and are just pure noise.   Whereas when alpha = 10 the test correlation was much higher showing that the forest was able to detect the shared structure among the stocks and use that structure to predict the target.
#
# **results from randomized CV search with alpha 0 and alpha 10**
#
# alpha = 0:
#
# tree with best parameters at alpha = 0 shows the following:
#
# Correlation near 0 means no relationship between predictions and truth
# small negative R2 means model is worse than predicting the mean
# MAE of 0.8 means predictions are basically random noise
#
# this is what we expect since all stocks (if alpha =0) are random noise and there is nothing there for the model to learn on.   if all features are random noise then no features contain info on the target.
#
# alpha = 10:
#
# tree with best parameters at alpha = 10 shows the following:
# correlation of almost 1 showing great relationship between predicions and true.    almost a perfect linear relationship
# R2 of .986 means that the model explains 98.6% of the variance.
# MAE of .9401 which is small relative to the scale.
#
# Key results:
# Correlation ≈ 0.993
# R² ≈ 0.986
# MAE ≈ 0.94
# What this means:
# Correlation ≈ 0.993 → almost perfect linear relationship
# R² ≈ 0.986 → model explains 98.6% of variance
# MAE is small relative to scale → predictions are very accurate
#
# all of this means that with an alpha of 10 the model was able to learn the data.
#
# the best parameters at alpha = 10:
#
# number of estimators = 200 shows more stability when actual signal exists
# max depth = none shows that trees are allowed to grow fully and the model is captureing complex structure in the data
# max features = 0.5 showing that each split only sees half of the feaures and this will help to isolate the truly relevant stocks.
# min samples = 20 and min leafs = 2 shows some regularization. i.e. this prevents overfitting noise in the data over the signal.
#
# **model evaluation metrics**
#
# i chose R2.  this metric measures how well a model explains the variation in the target variable (as compared to just using the mean of the dataset, y axis).   its values can be interpreted as follows:
#
# 1:   perfect prediction
# 0:   no bette than predicting the mean
# <0:  worse than predicting the mean
#
# I chose R2 because its scale independent (unlike MAE OR RMSE) and directly measures how well the model captures the structure in the data and is easy to interpret as a percentage of the exlained error.  in the data we were looking at when alpha = 0 then R2 is slighly negative which means that with an alpha of 0 the model performed worse than just predicting the average.  however with an alpha = 10 the R2 is almost 1 meaning that the model explains almost all of the variance in the data.

# %% [markdown]
# # 4. Storytelling With Data plot

# %% [markdown]
# Reproduce any graph of your choice in chapter six (p. 151-163) of the Storytelling With Data book as best you can. You do not have to get the exact data values right, just the overall look and feel.

# %%
from matplotlib.ticker import FuncFormatter, MultipleLocator

days_progress = list(range(0, 11))
progress = [0, 3000, 12000, 17000, 20000, 22000, 25000, 28000, 30000, 32000, 33967]

days_last_year = list(range(0, 31))
last_year = [
    0, 3000, 5000, 6500, 8000, 10000, 12000, 14000, 17000, 19000,
    20000, 21000, 25000, 26000, 28000, 30000, 34000, 35000, 37000,
    39000, 40000, 42000, 43000, 45000, 45500, 46000, 47000, 48000,
    49000, 50500, 51400]

fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(days_progress, progress, color="darkblue", linewidth=3)
ax.plot(days_last_year, last_year, color="lightskyblue", linewidth=1.8)

ax.plot(days_progress[-1], progress[-1], 'o', color="darkblue")
ax.plot(days_last_year[-1], last_year[-1], 'o', color="lightskyblue")

goal = 50000
ax.axhline(goal, color="gray", linewidth=1.5)
ax.text(0.3, goal + 300, "GOAL", ha="left", va="bottom", color="gray", fontsize=10)

ax.text(days_progress[-1] + 0.4, progress[-1], f"${progress[-1]:,}",
        color="darkblue", va="center", ha="left", fontsize=10, fontweight="bold")

ax.text(days_last_year[-1] + 0.4, last_year[-1], f"${last_year[-1]:,}",
        color="lightskyblue", va="center", ha="left", fontsize=10)

ax.text(days_progress[-1] + 0.4, progress[-1] - 2000, "Progress to date",
        color="darkblue", va="top", ha="left", fontsize=10, fontweight="bold")

ax.text(days_last_year[-1] + 0.4, last_year[-1] - 2000, "Last year",
        color="lightskyblue", va="top", ha="left", fontsize=10)

ax.set_title("Annual giving  campaign progress", loc="left", pad=15)

ax.set_xlabel("Days since campaign launch", loc="left")
ax.set_ylabel("Money raised", loc="top")

ax.xaxis.set_major_locator(MultipleLocator(5))
ax.yaxis.set_major_locator(MultipleLocator(10000))

ax.yaxis.set_major_formatter(FuncFormatter(lambda x, pos: f"${int(x):,}"))

ax.set_xlim(0, 30)
ax.set_ylim(0, 60000)

ax.grid(False)

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

plt.tight_layout()
plt.show()
